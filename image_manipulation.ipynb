# %% [markdown]
# <a href="https://colab.research.google.com/github/Anujakhatri/Machine-learning/blob/main/image_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

# Create a black image
img = np.zeros((400, 400, 3), dtype="uint8")

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
